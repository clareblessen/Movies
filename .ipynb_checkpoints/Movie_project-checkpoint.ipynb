# %%
#instantiate cursor and load libraries
import json
import pandas as pd
import requests
import mysql.connector 
import config
cnx = mysql.connector .connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd
)

print(cnx)

# %%
#rename cursor
cursor = cnx.cursor()

# %%
#create database
from mysql.connector import errorcode
db_name = 'Movies'

def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)

try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)

# %%
#specify database for connection
db = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = "Movies")

cursor = db.cursor()

# %%
# api_key = '__'
# headers = {
#         'Authorization': 'Bearer {}'.format(api_key),
#     }
# url_params = { action=query?
#              }
# Out:
#   File "<ipython-input-6-06893dfe6297>", line 5
#     url_params = { action=query?
#                          ^
# SyntaxError: invalid syntax

# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
page = requests.get('https://www.imdb.com/search/title/?title_type=feature&year=2018-01-01,2018-12-31&sort=boxoffice_gross_us,desc')
page
# Out:
# <Response [200]>

# %%
soup = BS(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Feature Film,
# Released between 2018-01-01 and 2018-12-31
# (Sorted by US Box Office Descending) - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
# ...

# %%
info = soup.find_all(id = 'main')

# %%
movie = info[0].find_all(class_='lister-item mode-advanced')
movie
# Out:
# [<div class="lister-item mode-advanced">
#  <div class="lister-top-right">
#  <div class="ribbonize" data-caller="filmosearch" data-tconst="tt1825683"></div>
#  </div>
#  <div class="lister-item-image float-left">
#  <a href="/title/tt1825683/"> <img alt="Black Panther" class="loadlate" data-tconst="tt1825683" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
#  </a> </div>
#  <div class="lister-item-content">
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt1825683/">Black Panther</a>
#  <span class="lister-item-year text-muted unbold">(2018)</span>
#  </h3>
#  <p class="text-muted">
#  <span class="certificate">PG-13</span>
#  <span class="ghost">|</span>
#  <span class="runtime">134 min</span>
# ...

# %%
one = movie[0]
m = one.get_text(strip='True')

# %%
all_movies = [m.get_text(strip='True') for m in movie]
all_movies
# Out:
# ["1.Black Panther(2018)PG-13|134 min|Action, Adventure, Sci-Fi7.3Rate this123456789107.3/10X88MetascoreT'Challa, heir to the hidden but advanced kingdom of Wakanda, must step forward to lead his people into a new future and must confront a challenger from his country's past.Director:Ryan Coogler|Stars:Chadwick Boseman,Michael B. Jordan,Lupita Nyong'o,Danai GuriraVotes:548,058|Gross:$700.06M",
#  '2.Avengers: Infinity War(2018)PG-13|149 min|Action, Adventure, Sci-Fi8.5Rate this123456789108.5/10X68MetascoreThe Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.Directors:Anthony Russo,Joe Russo|Stars:Robert Downey Jr.,Chris Hemsworth,Mark Ruffalo,Chris EvansVotes:720,140|Gross:$678.82M',
# ...

# %%
one
# Out:
# <div class="lister-item mode-advanced">
# <div class="lister-top-right">
# <div class="ribbonize" data-caller="filmosearch" data-tconst="tt1825683"></div>
# </div>
# <div class="lister-item-image float-left">
# <a href="/title/tt1825683/"> <img alt="Black Panther" class="loadlate" data-tconst="tt1825683" height="98" loadlate="https://m.media-amazon.com/images/M/MV5BMTg1MTY2MjYzNV5BMl5BanBnXkFtZTgwMTc4NTMwNDI@._V1_UX67_CR0,0,67,98_AL_.jpg" src="https://m.media-amazon.com/images/G/01/imdb/images/nopicture/large/film-184890147._CB470041630_.png" width="67"/>
# </a> </div>
# <div class="lister-item-content">
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt1825683/">Black Panther</a>
# <span class="lister-item-year text-muted unbold">(2018)</span>
# </h3>
# <p class="text-muted">
# <span class="certificate">PG-13</span>
# <span class="ghost">|</span>
# <span class="runtime">134 min</span>
# <span class="ghost">|</span>
# ...

# %%
def parse_movie(movie):

    def find_fk(movie):
        ids = []
        for m in movie:
            id = m.find (class_="starBarWidget")['id']
            ids.append(id)
        return ids
# find_fk(movie)

# %%
# metascore = one.find(class_="metascore mixed").get_text()
# metascore
# metascores = [score.get_text() for score in all_movies.select(".lister-item mode-advanced .metascore mixed")]
# metascores
def get_score(movie):
    metascores = []
    for score in movie:
        metascore1 = score.find(class_="metascore mixed")
        print(metascore1)
        if metascore1 = 'None':
            then metascore = 'None'
        else:
            
#         metascores.append(metascore1)
#     return metascores

get_score(movie)
# Out:
# None
# None
# None
# <span class="metascore mixed">51        </span>
# <span class="metascore mixed">55        </span>
# None
# <span class="metascore mixed">51        </span>
# None
# None
# <span class="metascore mixed">49        </span>
# None
# None
# None
# None
# None
# None
# None
# None
# <span class="metascore mixed">54        </span>
# <span class="metascore mixed">52        </span>
# None
# <span class="metascore mixed">46        </span>
# None
# None
# None
# <span class="metascore mixed">60        </span>
# <span class="metascore mixed">46        </span>
# None
# <span class="metascore mixed">51        </span>
# <span class="metascore mixed">58        </span>
# <span class="metascore mixed">50        </span>
# <span class="metascore mixed">45        </span>
# <span class="metascore mixed">53        </span>
# None
# <span class="metascore mixed">60        </span>
# None
# None
# <span class="metascore mixed">60        </span>
# ...

# %%
def get_titles(movie):

    titles = []
    for one in movie:
        title = one.find('img')['alt']
        titles.append(title) 
    return titles

# %%
def get_stars(movie):
    stars = []
    for one in movie:
        x = one.find(class_='inline-block ratings-imdb-rating')
        stars.append(x['data-value'])
    return stars
# get_stars(movie)

# %%
def get_year(movie):
    
    years = []
    for one in movie:
        year = one.find(class_="lister-item-year text-muted unbold").get_text()
        parsed_year = year[-5:-1]
        years.append(parsed_year)
    return years
# get_year(movie)

# %%
def get_metascore():
    
    metascores = []
    for
# Out:
#   File "<ipython-input-20-2af8f0302367>", line 4
#     for
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.DataFrame(all_movies)

# %%
df.head()
# Out:
#                                                    0
# 0  1.Black Panther(2018)PG-13|134 min|Action, Adv...
# 1  2.Avengers: Infinity War(2018)PG-13|149 min|Ac...
# 2  3.Incredibles 2(2018)PG|118 min|Animation, Act...
# 3  4.Jurassic World: Fallen Kingdom(2018)PG-13|12...
# 4  5.Aquaman(2018)PG-13|143 min|Action, Adventure...
